# %%
n=int (input("Enter Number:"))
if(n%3==0 and n%5!=0):
    print("FIZZ!!")
elif(n%5==0 and  n%3!=0):
    print("BUZZ!!")
elif(n%3==0 and n%5==0):
    print("FIZZ AND BUZZ!! ")
else:
    print("NONE!")
# Out:
# FIZZ AND BUZZ!!
