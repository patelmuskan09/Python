# %%
print("LALLALALALLAL")
# Out:
# LALLALALALLAL

# %%
c=int (input("Enter IN DEGREE CELCIUS:"))
f=9/5*c+32
print("In Farenheit:", f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c=int (input("Enter IN DEGREE CELCIUS:"))
#       2 f=9/5*c+32
#       3 print("In Farenheit:", f)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print("HEYYYYYYYYY GUYSSSSSSSS")
# Out:
# HEYYYYYYYYY GUYSSSSSSSS
